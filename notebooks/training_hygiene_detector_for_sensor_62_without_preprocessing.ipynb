# %%
import PAC_experiment_class as pac
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
import tensorflow as tf
from tensorflow.python.client import timeline
import time

# %%
experiment_directory_suffix = "hygiene_detector_for_sensor_62_without_preprocessing"
experiment_directory_name = None

# %%
def initialize_params_for_experiment():
    params_initialization_for_training = {}
    params_initialization_for_training['training_path_zero_labeled'] = "data/0/training_filenames_62.txt"
    params_initialization_for_training['training_path_one_labeled'] = "data/1/training_filenames_62.txt"
    params_initialization_for_training['batch_size'] = 64
    params_initialization_for_training['stage_of_development'] = "training"
    params_initialization_for_training['learning_rate'] = 0.001
    params_initialization_for_training['learning_rate_decay_factor'] = 0.99
    params_initialization_for_training['max_steps'] = None
    params_initialization_for_training['num_epochs'] = 1
    params_initialization_for_training['use_preprocessing'] = False
    return pac.initialize_params(experiment_directory_name,
                          experiment_directory_suffix,
                          "training",
                          params_initialization_for_training=params_initialization_for_training)

# %%
params, filenames_of_training_images, labels_of_training_images = initialize_params_for_experiment()
pac.run_training_with_feed_dictionary(params, "/gpu:0", filenames_of_training_images, labels_of_training_images)
# Out:
# Created model with fresh parameters.
# Will not use preprocessing
# Length of Time (in seconds) for preprocessing 111.99588894844055
# Batch Size of List of Filenames 64
# Batch Size of List of Label Images 64
# global step 1 learning rate 0.0010 step-time 12.60 loss 0.69
# Batch Size of List of Filenames 64
# Batch Size of List of Label Images 64
# global step 2 learning rate 0.0010 step-time 11.29 loss 0.68
# Batch Size of List of Filenames 64
# Batch Size of List of Label Images 64
# global step 3 learning rate 0.0010 step-time 10.68 loss 0.71
# Batch Size of List of Filenames 64
# Batch Size of List of Label Images 64
# global step 4 learning rate 0.0010 step-time 10.68 loss 0.69
# Batch Size of List of Filenames 64
# Batch Size of List of Label Images 64
# global step 5 learning rate 0.0010 step-time 11.40 loss 0.69
# Batch Size of List of Filenames 64
# Batch Size of List of Label Images 64
# global step 6 learning rate 0.0010 step-time 10.56 loss 0.71
# Batch Size of List of Filenames 64
# Batch Size of List of Label Images 64
# global step 7 learning rate 0.0010 step-time 13.10 loss 0.69
# Batch Size of List of Filenames 64
# Batch Size of List of Label Images 64
# global step 8 learning rate 0.0010 step-time 12.91 loss 0.68
# Batch Size of List of Filenames 64
# Batch Size of List of Label Images 64
# global step 9 learning rate 0.0010 step-time 13.64 loss 0.69
# Batch Size of List of Filenames 64
# Batch Size of List of Label Images 64
# global step 10 learning rate 0.0010 step-time 14.79 loss 0.70
# Batch Size of List of Filenames 64
# Batch Size of List of Label Images 64
# global step 11 learning rate 0.0010 step-time 13.60 loss 0.70
# Batch Size of List of Filenames 64
# Batch Size of List of Label Images 64
# global step 12 learning rate 0.0010 step-time 11.08 loss 0.66
# Batch Size of List of Filenames 64
# Batch Size of List of Label Images 64
# global step 13 learning rate 0.0010 step-time 12.14 loss 0.70
# Batch Size of List of Filenames 64
# Batch Size of List of Label Images 64
# global step 14 learning rate 0.0010 step-time 12.71 loss 0.70
# Batch Size of List of Filenames 64
# Batch Size of List of Label Images 64
# global step 15 learning rate 0.0010 step-time 12.56 loss 0.68
# Batch Size of List of Filenames 64
# Batch Size of List of Label Images 64
# global step 16 learning rate 0.0010 step-time 12.71 loss 0.68
# Batch Size of List of Filenames 64
# Batch Size of List of Label Images 64
# global step 17 learning rate 0.0010 step-time 12.66 loss 0.68
# Batch Size of List of Filenames 64
# Batch Size of List of Label Images 64
# global step 18 learning rate 0.0010 step-time 12.49 loss 0.72
# Batch Size of List of Filenames 64
# Batch Size of List of Label Images 64
# global step 19 learning rate 0.0010 step-time 13.39 loss 0.70
# Batch Size of List of Filenames 64
# Batch Size of List of Label Images 64
# global step 20 learning rate 0.0010 step-time 12.50 loss 0.68
# Batch Size of List of Filenames 64
# Batch Size of List of Label Images 64
# global step 21 learning rate 0.0010 step-time 12.46 loss 0.68
# Batch Size of List of Filenames 64
# Batch Size of List of Label Images 64
# global step 22 learning rate 0.0010 step-time 12.04 loss 0.70
# Batch Size of List of Filenames 64
# Batch Size of List of Label Images 64
# global step 23 learning rate 0.0010 step-time 12.57 loss 0.67
# Batch Size of List of Filenames 64
# Batch Size of List of Label Images 64
# global step 24 learning rate 0.0010 step-time 12.62 loss 0.70
# Batch Size of List of Filenames 64
# Batch Size of List of Label Images 64
# global step 25 learning rate 0.0010 step-time 12.26 loss 0.70
# Batch Size of List of Filenames 64
# Batch Size of List of Label Images 64
# global step 26 learning rate 0.0010 step-time 11.61 loss 0.68
# Batch Size of List of Filenames 64
# Batch Size of List of Label Images 64
# global step 27 learning rate 0.0010 step-time 11.83 loss 0.69
# Batch Size of List of Filenames 64
# Batch Size of List of Label Images 64
# global step 28 learning rate 0.0010 step-time 10.97 loss 0.67
# Batch Size of List of Filenames 64
# Batch Size of List of Label Images 64
# global step 29 learning rate 0.0010 step-time 10.97 loss 0.68
# Batch Size of List of Filenames 64
# Batch Size of List of Label Images 64
# global step 30 learning rate 0.0010 step-time 11.30 loss 0.67
# Batch Size of List of Filenames 64
# Batch Size of List of Label Images 64
# global step 31 learning rate 0.0010 step-time 11.45 loss 0.69
# Batch Size of List of Filenames 64
# Batch Size of List of Label Images 64
# global step 32 learning rate 0.0010 step-time 11.77 loss 0.69
# Batch Size of List of Filenames 64
# Batch Size of List of Label Images 64
# global step 33 learning rate 0.0009 step-time 11.37 loss 0.66
# Batch Size of List of Filenames 64
# Batch Size of List of Label Images 64
# global step 34 learning rate 0.0009 step-time 11.20 loss 0.70
# Batch Size of List of Filenames 64
# Batch Size of List of Label Images 64
# global step 35 learning rate 0.0009 step-time 11.40 loss 0.69
# Batch Size of List of Filenames 64
# Batch Size of List of Label Images 64
# global step 36 learning rate 0.0009 step-time 11.50 loss 0.70
# Batch Size of List of Filenames 64
# Batch Size of List of Label Images 64
# global step 37 learning rate 0.0009 step-time 11.79 loss 0.67
# Batch Size of List of Filenames 64
# Batch Size of List of Label Images 64
# global step 38 learning rate 0.0009 step-time 11.43 loss 0.69
# Batch Size of List of Filenames 64
# Batch Size of List of Label Images 64
# global step 39 learning rate 0.0009 step-time 11.42 loss 0.67
# Batch Size of List of Filenames 64
# Batch Size of List of Label Images 64
# global step 40 learning rate 0.0009 step-time 12.50 loss 0.68
# Batch Size of List of Filenames 64
# Batch Size of List of Label Images 64
# global step 41 learning rate 0.0009 step-time 12.98 loss 0.66
# Batch Size of List of Filenames 64
# Batch Size of List of Label Images 64
# global step 42 learning rate 0.0009 step-time 12.31 loss 0.66
# Batch Size of List of Filenames 64
# Batch Size of List of Label Images 64
# global step 43 learning rate 0.0009 step-time 12.30 loss 0.66
# Batch Size of List of Filenames 64
# Batch Size of List of Label Images 64
# global step 44 learning rate 0.0009 step-time 11.69 loss 0.69
# Batch Size of List of Filenames 64
# Batch Size of List of Label Images 64
# global step 45 learning rate 0.0009 step-time 12.13 loss 0.66
# Batch Size of List of Filenames 64
# Batch Size of List of Label Images 64
# global step 46 learning rate 0.0009 step-time 12.15 loss 0.67
# Batch Size of List of Filenames 64
# Batch Size of List of Label Images 64
# global step 47 learning rate 0.0009 step-time 11.59 loss 0.65
# Batch Size of List of Filenames 64
# Batch Size of List of Label Images 64
# global step
loss 0.64
# Batch Size of List of Filenames 64
# Batch Size of List of Label Images 64
# global step 119 learning rate 0.0008 step-time 11.65 loss 0.66
# Batch Size of List of Filenames 64
# Batch Size of List of Label Images 64
# global step 120 learning rate 0.0008 step-time 12.28 loss 0.62
# Batch Size of List of Filenames 64
# Batch Size of List of Label Images 64
# global step 121 learning rate 0.0008 step-time 10.36 loss 0.65
# Batch Size of List of Filenames 64
# Batch Size of List of Label Images 64
# global step 122 learning rate 0.0008 step-time 12.14 loss 0.64
# Batch Size of List of Filenames 64
# Batch Size of List of Label Images 64
# global step 123 learning rate 0.0008 step-time 11.07 loss 0.61
# Batch Size of List of Filenames 64
# Batch Size of List of Label Images 64
# global step 124 learning rate 0.0008 step-time 10.71 loss 0.62
# Batch Size of List of Filenames 64
# Batch Size of List of Label Images 64
# global step 125 learning rate 0.0008 step-time 11.08 loss 0.65
# Batch Size of List of Filenames 64
# Batch Size of List of Label Images 64
# global step 126 learning rate 0.0008 step-time 10.62 loss 0.65
# Batch Size of List of Filenames 64
# Batch Size of List of Label Images 64
# global step 127 learning rate 0.0008 step-time 10.41 loss 0.65
# Batch Size of List of Filenames 64
# Batch Size of List of Label Images 64
# global step 128 learning rate 0.0008 step-time 10.39 loss 0.65
# Batch Size of List of Filenames 64
# Batch Size of List of Label Images 64
# global step 129 learning rate 0.0008 step-time 10.33 loss 0.67
# Batch Size of List of LAST Filenames 64
# Batch Size of List of LAST Label Images 64
# global step 130 learning rate 0.0008 step-time 10.03 loss 0.61

# %%
def initialize_params_for_resuming_training_from_checkpoint():
    params_initialization_for_resume_training = {}
    params_initialization_for_resume_training['resume_training'] = True
    params_initialization_for_resume_training['training_path_zero_labeled'] = "data/0/training_filenames_62.txt"
    params_initialization_for_resume_training['training_path_one_labeled'] = "data/1/training_filenames_62.txt"
    params_initialization_for_resume_training['data_dir'] = 'data'
    params_initialization_for_resume_training['logs_dir'] = 'logs'
    params_initialization_for_resume_training['max_steps'] = 4
    params_initialization_for_resume_training['num_epochs'] = 1
    params_initialization_for_resume_training['batch_size'] = 32
    params_initialization_for_resume_training['use_preprocessing'] = False
    return pac.initialize_params(experiment_directory_name,
           experiment_directory_suffix,
           "resume_training",
           params_initialization_for_resume_training=params_initialization_for_resume_training)

# %%
params, filenames_of_resume_training_images, labels_of_resume_training_images = initialize_params_for_resuming_training_from_checkpoint()
pac.run_training_with_feed_dictionary(params, "/gpu:0", filenames_of_resume_training_images, labels_of_resume_training_images)

# %%
def initialize_params_for_evaluation_from_checkpoint():
    params_initialization_for_evaluation = {}
    params_initialization_for_evaluation['evaluate_model'] = True
    params_initialization_for_evaluation['resume_training'] = False
    params_initialization_for_evaluation['stage_of_development'] = "evaluation"
    params_initialization_for_evaluation['dev_path_zero_labeled'] = "data/0/dev_filenames_62.txt"
    params_initialization_for_evaluation['dev_path_one_labeled'] = "data/1/dev_filenames_62.txt"
    params_initialization_for_evaluation['data_dir'] = 'data'
    params_initialization_for_evaluation['logs_dir'] = 'logs'
    params_initialization_for_evaluation['max_steps'] = None
    params_initialization_for_evaluation['num_epochs'] = 1
    params_initialization_for_evaluation['batch_size'] = 32
    params_initialization_for_evaluation['use_preprocessing'] = False
    return pac.initialize_params(experiment_directory_name,
                                    experiment_directory_suffix,
                                    "evaluation",
                                    params_initialization_for_evaluation=params_initialization_for_evaluation)

# %%
params, filenames_of_evaluation_images, labels_of_evaluation_images = initialize_params_for_evaluation_from_checkpoint()
pac.evaluate_model_with_feed_dictionary(params, "/gpu:0", filenames_of_evaluation_images, labels_of_evaluation_images)
# Out:
# Reading model parameters from logs/0000000029_experiment_2018-01-17_21:53:44_hygiene_detector_for_sensor_62_without_preprocessing/translate.ckpt-130
# Done creating the model.
# False
# Length of Time (in seconds) for preprocessing 22.398792028427124
# Accuracy For Current Batch: 0.78125
# Accuracy For Current Batch: 0.8125
# Accuracy For Current Batch: 0.78125
# Accuracy For Current Batch: 0.8125
# Accuracy For Current Batch: 0.8125
# Accuracy For Current Batch: 0.78125
# Accuracy For Current Batch: 0.65625
# Accuracy For Current Batch: 0.8125
# Accuracy For Current Batch: 0.8125
# Accuracy For Current Batch: 0.71875
# Accuracy For Current Batch: 0.84375
# Accuracy For Current Batch: 0.875
# Accuracy For Current Batch: 0.78125
# Accuracy For Current Batch: 0.875
# Accuracy For Current Batch: 0.65625
# Accuracy For Current Batch: 0.65625
# Accuracy For Current Batch: 0.65625
# Accuracy For Current Batch: 0.8125
# Accuracy For Current Batch: 0.8125
# Accuracy For Current Batch: 0.78125
# Accuracy For Current Batch: 0.78125
# Accuracy For Current Batch: 0.96875
# Accuracy For Current Batch: 0.875
# Accuracy For Current Batch: 0.875
# Accuracy For Current Batch: 0.71875
# Accuracy For Current Batch: 0.84375
# Accuracy For Current Batch: 0.75
# Accuracy For Current Batch: 0.84375
# Accuracy For Current Batch: 0.71875
# Accuracy For Current Batch: 0.8125
# Accuracy For Current Batch: 0.8125
# Accuracy For Current Batch: 0.625
# Accuracy For Current Batch: 0.8125
# Accuracy For Current Batch: 0.8125
# Accuracy For Current Batch: 0.75
# Accuracy For Current Batch: 0.84375
# Accuracy For Current Batch: 0.71875
# Accuracy For Current Batch: 0.625
# Accuracy For Current Batch: 0.78125
# Accuracy For Current Batch: 0.8125
# Accuracy For Current Batch: 0.8125
# Accuracy For Current Batch: 0.71875
# Accuracy For Current Batch: 0.84375
# Accuracy For Current Batch: 0.84375
# Accuracy For Current Batch: 0.75
# Accuracy For Current Batch: 0.875
# Accuracy For Current Batch: 0.75
# Accuracy For Current Batch: 0.8125
# Accuracy For Current Batch: 0.8125
# Accuracy For Current Batch: 0.75
# Accuracy For Current Batch: 0.78125
# Accuracy For Current Batch: 0.71875
# Accuracy For Current Batch: 0.90625
# Accuracy For Current Batch: 0.75
# Accuracy For Current Batch: 0.84375
# Accuracy For Current Batch: 0.84375
# Accuracy For Current Batch: 0.8125
# Accuracy For Current Batch: 0.875
# Accuracy For Current Batch: 0.6875
# Accuracy For Current Batch: 0.6875
# Accuracy For Current Batch: 0.71875
# Accuracy For Current Batch: 0.75
# Accuracy For Current Batch: 0.84375
# Accuracy For Current Batch: 0.8125
# Accuracy For Current Batch: 0.84375
# Accuracy For Current Batch: 0.84375
# Accuracy For Current Batch: 0.84375
# Accuracy For Current Batch: 0.9375
# Accuracy For Current Batch: 0.75
# Accuracy For Current Batch: 0.90625
# Accuracy For Current Batch: 0.71875
# Accuracy For Current Batch: 0.75
# Accuracy For Current Batch: 0.75
# Accuracy For Current Batch: 0.75
# Accuracy For Current Batch: 0.84375
# Average Accuracy Across Batches: 0.79
