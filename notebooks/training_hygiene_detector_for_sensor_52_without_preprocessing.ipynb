# %%
import PAC_experiment_class as pac
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
import tensorflow as tf
from tensorflow.python.client import timeline
import time

# %%
experiment_directory_suffix = "hygiene_detector_for_sensor_52_without_preprocessing"
experiment_directory_name = None

# %%
def initialize_params_for_experiment():
    params_initialization_for_training = {}
    params_initialization_for_training['training_path_zero_labeled'] = "data/0/training_filenames_52.txt"
    params_initialization_for_training['training_path_one_labeled'] = "data/1/training_filenames_52.txt"
    params_initialization_for_training['batch_size'] = 64
    params_initialization_for_training['stage_of_development'] = "training"
    params_initialization_for_training['learning_rate'] = 0.001
    params_initialization_for_training['learning_rate_decay_factor'] = 0.99
    params_initialization_for_training['max_steps'] = None
    params_initialization_for_training['num_epochs'] = 1
    params_initialization_for_training['use_preprocessing'] = False
    return pac.initialize_params(experiment_directory_name,
                          experiment_directory_suffix,
                          "training",
                          params_initialization_for_training=params_initialization_for_training)

# %%
params, filenames_of_training_images, labels_of_training_images = initialize_params_for_experiment()
pac.run_training_with_feed_dictionary(params, "/gpu:0", filenames_of_training_images, labels_of_training_images)
# Out:
# Created model with fresh parameters.
# Will not use preprocessing
# Length of Time (in seconds) for preprocessing 116.48702383041382
# Batch Size of List of Filenames 64
# Batch Size of List of Label Images 64
# global step 1 learning rate 0.0010 step-time 10.08 loss 0.70
# Batch Size of List of Filenames 64
# Batch Size of List of Label Images 64
# global step 2 learning rate 0.0010 step-time 7.97 loss 0.69
# Batch Size of List of Filenames 64
# Batch Size of List of Label Images 64
# global step 3 learning rate 0.0010 step-time 12.51 loss 0.70
# Batch Size of List of Filenames 64
# Batch Size of List of Label Images 64
# global step 4 learning rate 0.0010 step-time 11.85 loss 0.70
# Batch Size of List of Filenames 64
# Batch Size of List of Label Images 64
# global step 5 learning rate 0.0010 step-time 11.10 loss 0.68
# Batch Size of List of Filenames 64
# Batch Size of List of Label Images 64
# global step 6 learning rate 0.0010 step-time 11.05 loss 0.69
# Batch Size of List of Filenames 64
# Batch Size of List of Label Images 64
# global step 7 learning rate 0.0010 step-time 11.59 loss 0.68
# Batch Size of List of Filenames 64
# Batch Size of List of Label Images 64
# global step 8 learning rate 0.0010 step-time 11.00 loss 0.69
# Batch Size of List of Filenames 64
# Batch Size of List of Label Images 64
# global step 9 learning rate 0.0010 step-time 12.63 loss 0.70
# Batch Size of List of Filenames 64
# Batch Size of List of Label Images 64
# global step 10 learning rate 0.0010 step-time 12.22 loss 0.69
# Batch Size of List of Filenames 64
# Batch Size of List of Label Images 64
# global step 11 learning rate 0.0010 step-time 13.19 loss 0.69
# Batch Size of List of Filenames 64
# Batch Size of List of Label Images 64
# global step 12 learning rate 0.0010 step-time 13.28 loss 0.69
# Batch Size of List of Filenames 64
# Batch Size of List of Label Images 64
# global step 13 learning rate 0.0010 step-time 12.92 loss 0.70
# Batch Size of List of Filenames 64
# Batch Size of List of Label Images 64
# global step 14 learning rate 0.0010 step-time 10.84 loss 0.69
# Batch Size of List of Filenames 64
# Batch Size of List of Label Images 64
# global step 15 learning rate 0.0010 step-time 11.08 loss 0.68
# Batch Size of List of Filenames 64
# Batch Size of List of Label Images 64
# global step 16 learning rate 0.0010 step-time 11.58 loss 0.69
# Batch Size of List of Filenames 64
# Batch Size of List of Label Images 64
# global step 17 learning rate 0.0010 step-time 11.79 loss 0.69
# Batch Size of List of Filenames 64
# Batch Size of List of Label Images 64
# global step 18 learning rate 0.0010 step-time 12.40 loss 0.69
# Batch Size of List of Filenames 64
# Batch Size of List of Label Images 64
# global step 19 learning rate 0.0010 step-time 12.20 loss 0.69
# Batch Size of List of Filenames 64
# Batch Size of List of Label Images 64
# global step 20 learning rate 0.0010 step-time 10.84 loss 0.69
# Batch Size of List of Filenames 64
# Batch Size of List of Label Images 64
# global step 21 learning rate 0.0010 step-time 13.02 loss 0.69
# Batch Size of List of Filenames 64
# Batch Size of List of Label Images 64
# global step 22 learning rate 0.0010 step-time 12.75 loss 0.69
# Batch Size of List of Filenames 64
# Batch Size of List of Label Images 64
# global step 23 learning rate 0.0010 step-time 10.82 loss 0.70
# Batch Size of List of Filenames 64
# Batch Size of List of Label Images 64
# global step 24 learning rate 0.0010 step-time 11.90 loss 0.69
# Batch Size of List of Filenames 64
# Batch Size of List of Label Images 64
# global step 25 learning rate 0.0010 step-time 11.81 loss 0.69
# Batch Size of List of Filenames 64
# Batch Size of List of Label Images 64
# global step 26 learning rate 0.0010 step-time 12.53 loss 0.69
# Batch Size of List of Filenames 64
# Batch Size of List of Label Images 64
# global step 27 learning rate 0.0010 step-time 11.48 loss 0.69
# Batch Size of List of Filenames 64
# Batch Size of List of Label Images 64
# global step 28 learning rate 0.0010 step-time 10.85 loss 0.70
# Batch Size of List of Filenames 64
# Batch Size of List of Label Images 64
# global step 29 learning rate 0.0009 step-time 11.26 loss 0.69
# Batch Size of List of Filenames 64
# Batch Size of List of Label Images 64
# global step 30 learning rate 0.0009 step-time 10.47 loss 0.69
# Batch Size of List of Filenames 64
# Batch Size of List of Label Images 64
# global step 31 learning rate 0.0009 step-time 11.10 loss 0.69
# Batch Size of List of Filenames 64
# Batch Size of List of Label Images 64
# global step 32 learning rate 0.0009 step-time 11.29 loss 0.69
# Batch Size of List of Filenames 64
# Batch Size of List of Label Images 64
# global step 33 learning rate 0.0009 step-time 10.97 loss 0.69
# Batch Size of List of Filenames 64
# Batch Size of List of Label Images 64
# global step 34 learning rate 0.0009 step-time 10.82 loss 0.70
# Batch Size of List of Filenames 64
# Batch Size of List of Label Images 64
# global step 35 learning rate 0.0009 step-time 11.07 loss 0.69
# Batch Size of List of Filenames 64
# Batch Size of List of Label Images 64
# global step 36 learning rate 0.0009 step-time 11.49 loss 0.69
# Batch Size of List of Filenames 64
# Batch Size of List of Label Images 64
# global step 37 learning rate 0.0009 step-time 11.33 loss 0.68
# Batch Size of List of Filenames 64
# Batch Size of List of Label Images 64
# global step 38 learning rate 0.0009 step-time 11.15 loss 0.70
# Batch Size of List of Filenames 64
# Batch Size of List of Label Images 64
# global step 39 learning rate 0.0009 step-time 10.88 loss 0.69
# Batch Size of List of Filenames 64
# Batch Size of List of Label Images 64
# global step
# Batch Size of List of Filenames 64
# Batch Size of List of Label Images 64
# global step 165 learning rate 0.0007 step-time 9.22 loss 0.67
# Batch Size of List of Filenames 64
# Batch Size of List of Label Images 64
# global step 166 learning rate 0.0007 step-time 9.79 loss 0.67
# Batch Size of List of LAST Filenames 64
# Batch Size of List of LAST Label Images 64
# global step 167 learning rate 0.0007 step-time 9.41 loss 0.67

# %%
def initialize_params_for_resuming_training_from_checkpoint():
    params_initialization_for_resume_training = {}
    params_initialization_for_resume_training['resume_training'] = True
    params_initialization_for_resume_training['training_path_zero_labeled'] = "data/0/training_filenames_52.txt"
    params_initialization_for_resume_training['training_path_one_labeled'] = "data/1/training_filenames_52.txt"
    params_initialization_for_resume_training['data_dir'] = 'data'
    params_initialization_for_resume_training['logs_dir'] = 'logs'
    params_initialization_for_resume_training['max_steps'] = 4
    params_initialization_for_resume_training['num_epochs'] = 1
    params_initialization_for_resume_training['batch_size'] = 32
    params_initialization_for_resume_training['use_preprocessing'] = False
    return pac.initialize_params(experiment_directory_name,
           experiment_directory_suffix,
           "resume_training",
           params_initialization_for_resume_training=params_initialization_for_resume_training)

# %%
params, filenames_of_resume_training_images, labels_of_resume_training_images = initialize_params_for_resuming_training_from_checkpoint()
pac.run_training_with_feed_dictionary(params, "/gpu:0", filenames_of_resume_training_images, labels_of_resume_training_images)

# %%
def initialize_params_for_evaluation_from_checkpoint():
    params_initialization_for_evaluation = {}
    params_initialization_for_evaluation['evaluate_model'] = True
    params_initialization_for_evaluation['resume_training'] = False
    params_initialization_for_evaluation['stage_of_development'] = "evaluation"
    params_initialization_for_evaluation['dev_path_zero_labeled'] = "data/0/dev_filenames_52.txt"
    params_initialization_for_evaluation['dev_path_one_labeled'] = "data/1/dev_filenames_52.txt"
    params_initialization_for_evaluation['data_dir'] = 'data'
    params_initialization_for_evaluation['logs_dir'] = 'logs'
    params_initialization_for_evaluation['max_steps'] = None
    params_initialization_for_evaluation['num_epochs'] = 1
    params_initialization_for_evaluation['batch_size'] = 32
    params_initialization_for_evaluation['use_preprocessing'] = False
    return pac.initialize_params(experiment_directory_name,
                                    experiment_directory_suffix,
                                    "evaluation",
                                    params_initialization_for_evaluation=params_initialization_for_evaluation)

# %%
params, filenames_of_evaluation_images, labels_of_evaluation_images = initialize_params_for_evaluation_from_checkpoint()
pac.evaluate_model_with_feed_dictionary(params, "/gpu:0", filenames_of_evaluation_images, labels_of_evaluation_images)
# Out:
# Reading model parameters from logs/0000000027_experiment_2018-01-17_21:53:10_hygiene_detector_for_sensor_52_without_preprocessing/translate.ckpt-167
# Done creating the model.
# False
# Length of Time (in seconds) for preprocessing 22.89404797554016
# Accuracy For Current Batch: 0.6875
# Accuracy For Current Batch: 0.71875
# Accuracy For Current Batch: 0.6875
# Accuracy For Current Batch: 0.78125
# Accuracy For Current Batch: 0.71875
# Accuracy For Current Batch: 0.84375
# Accuracy For Current Batch: 0.78125
# Accuracy For Current Batch: 0.78125
# Accuracy For Current Batch: 0.84375
# Accuracy For Current Batch: 0.90625
# Accuracy For Current Batch: 0.78125
# Accuracy For Current Batch: 0.71875
# Accuracy For Current Batch: 0.75
# Accuracy For Current Batch: 0.75
# Accuracy For Current Batch: 0.71875
# Accuracy For Current Batch: 0.84375
# Accuracy For Current Batch: 0.59375
# Accuracy For Current Batch: 0.78125
# Accuracy For Current Batch: 0.78125
# Accuracy For Current Batch: 0.875
# Accuracy For Current Batch: 0.71875
# Accuracy For Current Batch: 0.90625
# Accuracy For Current Batch: 0.84375
# Accuracy For Current Batch: 0.71875
# Accuracy For Current Batch: 0.65625
# Accuracy For Current Batch: 0.84375
# Accuracy For Current Batch: 0.78125
# Accuracy For Current Batch: 0.78125
# Accuracy For Current Batch: 0.78125
# Accuracy For Current Batch: 0.71875
# Accuracy For Current Batch: 0.84375
# Accuracy For Current Batch: 0.78125
# Accuracy For Current Batch: 0.90625
# Accuracy For Current Batch: 0.8125
# Accuracy For Current Batch: 0.75
# Accuracy For Current Batch: 0.75
# Accuracy For Current Batch: 0.8125
# Accuracy For Current Batch: 0.75
# Accuracy For Current Batch: 0.84375
# Accuracy For Current Batch: 0.625
# Accuracy For Current Batch: 0.84375
# Accuracy For Current Batch: 0.84375
# Accuracy For Current Batch: 0.78125
# Accuracy For Current Batch: 0.75
# Accuracy For Current Batch: 0.84375
# Accuracy For Current Batch: 0.875
# Accuracy For Current Batch: 0.75
# Accuracy For Current Batch: 0.78125
# Accuracy For Current Batch: 0.71875
# Accuracy For Current Batch: 0.84375
# Accuracy For Current Batch: 0.8125
# Accuracy For Current Batch: 0.875
# Accuracy For Current Batch: 0.75
# Accuracy For Current Batch: 0.875
# Accuracy For Current Batch: 0.71875
# Accuracy For Current Batch: 0.84375
# Accuracy For Current Batch: 0.71875
# Accuracy For Current Batch: 0.71875
# Accuracy For Current Batch: 0.78125
# Accuracy For Current Batch: 0.8125
# Accuracy For Current Batch: 0.71875
# Accuracy For Current Batch: 0.90625
# Accuracy For Current Batch: 0.8125
# Accuracy For Current Batch: 0.71875
# Accuracy For Current Batch: 0.78125
# Accuracy For Current Batch: 0.75
# Accuracy For Current Batch: 0.84375
# Accuracy For Current Batch: 0.84375
# Accuracy For Current Batch: 0.90625
# Accuracy For Current Batch: 0.8125
# Accuracy For Current Batch: 0.6875
# Accuracy For Current Batch: 0.78125
# Accuracy For Current Batch: 0.75
# Accuracy For Current Batch: 0.8125
# Accuracy For Current Batch: 0.6875
# Accuracy For Current Batch: 0.8125
# Accuracy For Current Batch: 0.8125
# Accuracy For Current Batch: 0.75
# Accuracy For Current Batch: 0.78125
# Accuracy For Current Batch: 0.75
# Accuracy For Current Batch: 0.78125
# Accuracy For Current Batch: 0.8125
# Accuracy For Current Batch: 0.78125
# Accuracy For Current Batch: 0.8125
# Accuracy For Current Batch: 0.625
# Accuracy For Current Batch: 0.75
# Accuracy For Current Batch: 0.78125
# Accuracy For Current Batch: 0.75
# Accuracy For Current Batch: 0.8125
# Accuracy For Current Batch: 0.84375
# Accuracy For Current Batch: 0.8125
# Accuracy For Current Batch: 0.75
# Accuracy For Current Batch: 0.875
# Accuracy For Current Batch: 0.75
# Accuracy For Current Batch: 0.71875
# Accuracy For Current Batch: 0.6875
# Average Accuracy Across Batches: 0.7809244791666666
