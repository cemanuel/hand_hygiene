# %%
import PAC_experiment_class as pac
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
import tensorflow as tf
from tensorflow.python.client import timeline
import time

# %%
experiment_directory_suffix = "hygiene_detector_for_sensor_15"
experiment_directory_name = None

# %%
def initialize_params_for_experiment():
    params_initialization_for_training = {}
    params_initialization_for_training['training_path_zero_labeled'] = "data/0/training_filenames_15.txt"
    params_initialization_for_training['training_path_one_labeled'] = "data/1/training_filenames_15.txt"
    params_initialization_for_training['batch_size'] = 64
    params_initialization_for_training['stage_of_development'] = "training"
    params_initialization_for_training['learning_rate'] = 0.001
    params_initialization_for_training['learning_rate_decay_factor'] = 0.99
    params_initialization_for_training['max_steps'] = None
    params_initialization_for_training['num_epochs'] = 1
    return pac.initialize_params(experiment_directory_name,
                          experiment_directory_suffix,
                          "training",
                          params_initialization_for_training=params_initialization_for_training)

# %%
params, filenames_of_training_images, labels_of_training_images = initialize_params_for_experiment()
if params != None and filenames_of_training_images != None and labels_of_training_images != None:
    pac.run_training_with_feed_dictionary(params, "/gpu:0", filenames_of_training_images, labels_of_training_images)
# Out:
# Created model with fresh parameters.
# Length of Time (in seconds) for preprocessing 398.16428995132446
# Batch Size of List of Filenames 64
# Batch Size of List of Label Images 64
# global step 1 learning rate 0.0010 step-time 7.69 loss 0.71
# Batch Size of List of Filenames 64
# Batch Size of List of Label Images 64
# global step 2 learning rate 0.0010 step-time 7.81 loss 0.68
# Batch Size of List of Filenames 64
# Batch Size of List of Label Images 64
# global step 3 learning rate 0.0010 step-time 8.18 loss 0.66
# Batch Size of List of Filenames 64
# Batch Size of List of Label Images 64
# global step 4 learning rate 0.0010 step-time 8.05 loss 0.66
# Batch Size of List of Filenames 64
# Batch Size of List of Label Images 64
# global step 5 learning rate 0.0010 step-time 7.67 loss 0.65
# Batch Size of List of Filenames 64
# Batch Size of List of Label Images 64
# global step 6 learning rate 0.0010 step-time 7.42 loss 0.63
# Batch Size of List of Filenames 64
# Batch Size of List of Label Images 64
# global step 7 learning rate 0.0010 step-time 7.40 loss 0.65
# Batch Size of List of Filenames 64
# Batch Size of List of Label Images 64
# global step 8 learning rate 0.0010 step-time 7.25 loss 0.64
# Batch Size of List of Filenames 64
# Batch Size of List of Label Images 64
# global step 9 learning rate 0.0010 step-time 7.99 loss 0.64
# Batch Size of List of Filenames 64
# Batch Size of List of Label Images 64
# global step 10 learning rate 0.0010 step-time 8.14 loss 0.62
# Batch Size of List of Filenames 64
# Batch Size of List of Label Images 64
# global step 11 learning rate 0.0010 step-time 7.12 loss 0.62
# Batch Size of List of Filenames 64
# Batch Size of List of Label Images 64
# global step 12 learning rate 0.0010 step-time 6.79 loss 0.63
# Batch Size of List of Filenames 64
# Batch Size of List of Label Images 64
# global step 13 learning rate 0.0010 step-time 7.05 loss 0.59
# Batch Size of List of Filenames 64
# Batch Size of List of Label Images 64
# global step 14 learning rate 0.0010 step-time 6.86 loss 0.60
# Batch Size of List of Filenames 64
# Batch Size of List of Label Images 64
# global step 15 learning rate 0.0010 step-time 8.61 loss 0.61
# Batch Size of List of Filenames 64
# Batch Size of List of Label Images 64
# global step 16 learning rate 0.0010 step-time 7.94 loss 0.60
# Batch Size of List of Filenames 64
# Batch Size of List of Label Images 64
# global step 17 learning rate 0.0010 step-time 7.62 loss 0.60
# Batch Size of List of Filenames 64
# Batch Size of List of Label Images 64
# global step 18 learning rate 0.0010 step-time 9.32 loss 0.57
# Batch Size of List of Filenames 64
# Batch Size of List of Label Images 64
# global step 19 learning rate 0.0010 step-time 8.11 loss 0.58
# Batch Size of List of Filenames 64
# Batch Size of List of Label Images 64
# global step 20 learning rate 0.0010 step-time 7.85 loss 0.57
# Batch Size of List of Filenames 64
# Batch Size of List of Label Images 64
# global step 21 learning rate 0.0010 step-time 7.47 loss 0.57
# Batch Size of List of Filenames 64
# Batch Size of List of Label Images 64
# global step 22 learning rate 0.0010 step-time 7.71 loss 0.57
# Batch Size of List of Filenames 64
# Batch Size of List of Label Images 64
# global step 23 learning rate 0.0010 step-time 7.72 loss 0.56
# Batch Size of List of Filenames 64
# Batch Size of List of Label Images 64
# global step 24 learning rate 0.0010 step-time 8.53 loss 0.55
# Batch Size of List of Filenames 64
# Batch Size of List of Label Images 64
# global step 25 learning rate 0.0010 step-time 8.13 loss 0.53
# Batch Size of List of Filenames 64
# Batch Size of List of Label Images 64
# global step 26 learning rate 0.0010 step-time 9.44 loss 0.56
# Batch Size of List of Filenames 64
# Batch Size of List of Label Images 64
# global step 27 learning rate 0.0010 step-time 8.62 loss 0.56
# Batch Size of List of Filenames 64
# Batch Size of List of Label Images 64
# global step 28 learning rate 0.0010 step-time 6.36 loss 0.52
# Batch Size of List of Filenames 64
# Batch Size of List of Label Images 64
# global step 29 learning rate 0.0010 step-time 6.70 loss 0.51
# Batch Size of List of Filenames 64
# Batch Size of List of Label Images 64
# global step 30 learning rate 0.0010 step-time 5.93 loss 0.51
# Batch Size of List of Filenames 64
# Batch Size of List of Label Images 64
# global step 31 learning rate 0.0010 step-time 5.34 loss 0.50
# Batch Size of List of Filenames 64
# Batch Size of List of Label Images 64
# global step 32 learning rate 0.0010 step-time 5.32 loss 0.55
# Batch Size of List of Filenames 64
# Batch Size of List of Label Images 64
# global step 33 learning rate 0.0010 step-time 5.42 loss 0.52
# Batch Size of List of Filenames 64
# Batch Size of List of Label Images 64
# global step 34 learning rate 0.0010 step-time 6.20 loss 0.51
# Batch Size of List of Filenames 64
# Batch Size of List of Label Images 64
# global step 35 learning rate 0.0010 step-time 6.71 loss 0.53
# Batch Size of List of Filenames 64
# Batch Size of List of Label Images 64
# global step 36 learning rate 0.0010 step-time 8.34 loss 0.52
# Batch Size of List of Filenames 64
# Batch Size of List of Label Images 64
# global step 37 learning rate 0.0010 step-time 8.82 loss 0.49
# Batch Size of List of Filenames 64
# Batch Size of List of Label Images 64
# global step
loss 0.17
# Batch Size of List of Filenames 64
# Batch Size of List of Label Images 64
# global step 151 learning rate 0.0008 step-time 6.46 loss 0.21
# Batch Size of List of Filenames 64
# Batch Size of List of Label Images 64
# global step 152 learning rate 0.0008 step-time 6.93 loss 0.17
# Batch Size of List of Filenames 64
# Batch Size of List of Label Images 64
# global step 153 learning rate 0.0008 step-time 7.28 loss 0.15
# Batch Size of List of Filenames 64
# Batch Size of List of Label Images 64
# global step 154 learning rate 0.0008 step-time 8.43 loss 0.09
# Batch Size of List of Filenames 64
# Batch Size of List of Label Images 64
# global step 155 learning rate 0.0008 step-time 8.00 loss 0.15
# Batch Size of List of Filenames 64
# Batch Size of List of Label Images 64
# global step 156 learning rate 0.0008 step-time 7.90 loss 0.22
# Batch Size of List of Filenames 64
# Batch Size of List of Label Images 64
# global step 157 learning rate 0.0008 step-time 6.67 loss 0.20
# Batch Size of List of LAST Filenames 64
# Batch Size of List of LAST Label Images 64
# global step 158 learning rate 0.0008 step-time 6.30 loss 0.17

# %%
def initialize_params_for_resuming_training_from_checkpoint():
    params_initialization_for_resume_training = {}
    params_initialization_for_resume_training['resume_training'] = True
    params_initialization_for_resume_training['training_path_zero_labeled'] = "data/0/training_filenames_15.txt"
    params_initialization_for_resume_training['training_path_one_labeled'] = "data/1/training_filenames_15.txt"
    params_initialization_for_resume_training['data_dir'] = 'data'
    params_initialization_for_resume_training['logs_dir'] = 'logs'
    params_initialization_for_resume_training['max_steps'] = 4
    params_initialization_for_resume_training['num_epochs'] = 1
    params_initialization_for_resume_training['batch_size'] = 32
    return pac.initialize_params(experiment_directory_name,
           experiment_directory_suffix,
           "resume_training",
           params_initialization_for_resume_training=params_initialization_for_resume_training)

# %%
params, filenames_of_resume_training_images, labels_of_resume_training_images = initialize_params_for_resuming_training_from_checkpoint()
if params != None and filenames_of_resume_training_images != None and labels_of_resume_training_images != None:
    pac.run_training_with_feed_dictionary(params, "/gpu:0", filenames_of_resume_training_images, labels_of_resume_training_images)

# %%
def initialize_params_for_evaluation_from_checkpoint():
    params_initialization_for_evaluation = {}
    params_initialization_for_evaluation['evaluate_model'] = True
    params_initialization_for_evaluation['resume_training'] = False
    params_initialization_for_evaluation['stage_of_development'] = "evaluation"
    params_initialization_for_evaluation['dev_path_zero_labeled'] = "data/0/dev_filenames_15.txt"
    params_initialization_for_evaluation['dev_path_one_labeled'] = "data/1/dev_filenames_15.txt"
    params_initialization_for_evaluation['data_dir'] = 'data'
    params_initialization_for_evaluation['logs_dir'] = 'logs'
    params_initialization_for_evaluation['max_steps'] = None
    params_initialization_for_evaluation['num_epochs'] = 1
    params_initialization_for_evaluation['batch_size'] = 32
    return pac.initialize_params(experiment_directory_name,
                                    experiment_directory_suffix,
                                    "evaluation",
                                    params_initialization_for_evaluation=params_initialization_for_evaluation)

# %%
params, filenames_of_evaluation_images, labels_of_evaluation_images = initialize_params_for_evaluation_from_checkpoint()
if params != None and filenames_of_training_images != None and labels_of_training_images != None:
    pac.evaluate_model_with_feed_dictionary(params, "/gpu:0", filenames_of_evaluation_images, labels_of_evaluation_images)
# Out:
# Reading model parameters from logs/0000000007_experiment_2018-01-14_17:24:12_hygiene_detector_for_sensor_15/translate.ckpt-158
# Done creating the model.
# Length of Time (in seconds) for preprocessing 95.4707899093628
# Accuracy For Current Batch: 0.96875
# Accuracy For Current Batch: 0.96875
# Accuracy For Current Batch: 1.0
# Accuracy For Current Batch: 1.0
# Accuracy For Current Batch: 0.90625
# Accuracy For Current Batch: 1.0
# Accuracy For Current Batch: 1.0
# Accuracy For Current Batch: 1.0
# Accuracy For Current Batch: 1.0
# Accuracy For Current Batch: 1.0
# Accuracy For Current Batch: 1.0
# Accuracy For Current Batch: 1.0
# Accuracy For Current Batch: 1.0
# Accuracy For Current Batch: 1.0
# Accuracy For Current Batch: 1.0
# Accuracy For Current Batch: 0.90625
# Accuracy For Current Batch: 0.96875
# Accuracy For Current Batch: 0.96875
# Accuracy For Current Batch: 0.9375
# Accuracy For Current Batch: 1.0
# Accuracy For Current Batch: 0.9375
# Accuracy For Current Batch: 1.0
# Accuracy For Current Batch: 0.96875
# Accuracy For Current Batch: 0.96875
# Accuracy For Current Batch: 0.96875
# Accuracy For Current Batch: 0.90625
# Accuracy For Current Batch: 1.0
# Accuracy For Current Batch: 0.96875
# Accuracy For Current Batch: 1.0
# Accuracy For Current Batch: 0.96875
# Accuracy For Current Batch: 1.0
# Accuracy For Current Batch: 0.90625
# Accuracy For Current Batch: 0.9375
# Accuracy For Current Batch: 0.90625
# Accuracy For Current Batch: 0.96875
# Accuracy For Current Batch: 0.9375
# Accuracy For Current Batch: 0.96875
# Accuracy For Current Batch: 0.96875
# Accuracy For Current Batch: 0.96875
# Accuracy For Current Batch: 1.0
# Accuracy For Current Batch: 1.0
# Accuracy For Current Batch: 0.96875
# Accuracy For Current Batch: 1.0
# Accuracy For Current Batch: 0.96875
# Accuracy For Current Batch: 0.9375
# Accuracy For Current Batch: 0.96875
# Accuracy For Current Batch: 0.9375
# Accuracy For Current Batch: 1.0
# Accuracy For Current Batch: 0.9375
# Accuracy For Current Batch: 1.0
# Accuracy For Current Batch: 0.9375
# Accuracy For Current Batch: 1.0
# Accuracy For Current Batch: 0.96875
# Accuracy For Current Batch: 1.0
# Accuracy For Current Batch: 0.96875
# Accuracy For Current Batch: 0.9375
# Accuracy For Current Batch: 0.9375
# Accuracy For Current Batch: 0.96875
# Accuracy For Current Batch: 0.96875
# Accuracy For Current Batch: 0.9375
# Accuracy For Current Batch: 1.0
# Accuracy For Current Batch: 0.90625
# Accuracy For Current Batch: 1.0
# Accuracy For Current Batch: 1.0
# Accuracy For Current Batch: 0.96875
# Accuracy For Current Batch: 0.96875
# Accuracy For Current Batch: 0.9375
# Accuracy For Current Batch: 0.90625
# Accuracy For Current Batch: 0.96875
# Accuracy For Current Batch: 0.96875
# Accuracy For Current Batch: 0.96875
# Accuracy For Current Batch: 0.9375
# Accuracy For Current Batch: 0.90625
# Accuracy For Current Batch: 0.9375
# Accuracy For Current Batch: 0.96875
# Accuracy For Current Batch: 1.0
# Accuracy For Current Batch: 1.0
# Accuracy For Current Batch: 0.90625
# Accuracy For Current Batch: 0.96875
# Accuracy For Current Batch: 0.90625
# Accuracy For Current Batch: 0.9375
# Accuracy For Current Batch: 0.9375
# Accuracy For Current Batch: 0.96875
# Accuracy For Current Batch: 1.0
# Accuracy For Current Batch: 0.96875
# Accuracy For Current Batch: 1.0
# Accuracy For Current Batch: 0.9375
# Accuracy For Current Batch: 1.0
# Accuracy For Current Batch: 1.0
# Accuracy For Current Batch: 0.9375
# Accuracy For Current Batch: 0.96875
# Average Accuracy Across Batches: 0.967032967032967
