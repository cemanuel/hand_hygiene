# %%
import PAC_experiment_class as pac
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
import tensorflow as tf
from tensorflow.python.client import timeline
import time

# %%
experiment_directory_suffix = "hygiene_detector_for_sensor_02_without_preprocessing"
experiment_directory_name = None

# %%
def initialize_params_for_experiment():
    params_initialization_for_training = {}
    params_initialization_for_training['training_path_zero_labeled'] = "data/0/training_filenames_02.txt"
    params_initialization_for_training['training_path_one_labeled'] = "data/1/training_filenames_02.txt"
    params_initialization_for_training['batch_size'] = 64
    params_initialization_for_training['stage_of_development'] = "training"
    params_initialization_for_training['learning_rate'] = 0.001
    params_initialization_for_training['learning_rate_decay_factor'] = 0.99
    params_initialization_for_training['max_steps'] = None
    params_initialization_for_training['num_epochs'] = 1
    params_initialization_for_training['use_preprocessing'] = False
    return pac.initialize_params(experiment_directory_name,
                          experiment_directory_suffix,
                          "training",
                          params_initialization_for_training=params_initialization_for_training)

# %%
params, filenames_of_training_images, labels_of_training_images = initialize_params_for_experiment()
if params != None and filenames_of_training_images != None and labels_of_training_images != None:
    pac.run_training_with_feed_dictionary(params, "/gpu:0", filenames_of_training_images, labels_of_training_images)
# Out:
# Created model with fresh parameters.
# Length of Time (in seconds) for preprocessing 54.995609998703
# Batch Size of List of Filenames 64
# Batch Size of List of Label Images 64
# global step 1 learning rate 0.0010 step-time 4.60 loss 0.68
# Batch Size of List of Filenames 64
# Batch Size of List of Label Images 64
# global step 2 learning rate 0.0010 step-time 4.43 loss 0.70
# Batch Size of List of Filenames 64
# Batch Size of List of Label Images 64
# global step 3 learning rate 0.0010 step-time 3.83 loss 0.69
# Batch Size of List of Filenames 64
# Batch Size of List of Label Images 64
# global step 4 learning rate 0.0010 step-time 4.13 loss 0.70
# Batch Size of List of Filenames 64
# Batch Size of List of Label Images 64
# global step 5 learning rate 0.0010 step-time 3.76 loss 0.69
# Batch Size of List of Filenames 64
# Batch Size of List of Label Images 64
# global step 6 learning rate 0.0010 step-time 3.98 loss 0.68
# Batch Size of List of Filenames 64
# Batch Size of List of Label Images 64
# global step 7 learning rate 0.0010 step-time 3.86 loss 0.69
# Batch Size of List of Filenames 64
# Batch Size of List of Label Images 64
# global step 8 learning rate 0.0010 step-time 4.63 loss 0.67
# Batch Size of List of Filenames 64
# Batch Size of List of Label Images 64
# global step 9 learning rate 0.0010 step-time 4.84 loss 0.67
# Batch Size of List of Filenames 64
# Batch Size of List of Label Images 64
# global step 10 learning rate 0.0010 step-time 5.00 loss 0.68
# Batch Size of List of Filenames 64
# Batch Size of List of Label Images 64
# global step 11 learning rate 0.0010 step-time 4.88 loss 0.71
# Batch Size of List of Filenames 64
# Batch Size of List of Label Images 64
# global step 12 learning rate 0.0010 step-time 3.85 loss 0.68
# Batch Size of List of Filenames 64
# Batch Size of List of Label Images 64
# global step 13 learning rate 0.0010 step-time 4.00 loss 0.68
# Batch Size of List of Filenames 64
# Batch Size of List of Label Images 64
# global step 14 learning rate 0.0010 step-time 4.17 loss 0.69
# Batch Size of List of Filenames 64
# Batch Size of List of Label Images 64
# global step 15 learning rate 0.0010 step-time 4.21 loss 0.69
# Batch Size of List of Filenames 64
# Batch Size of List of Label Images 64
# global step 16 learning rate 0.0010 step-time 4.33 loss 0.69
# Batch Size of List of Filenames 64
# Batch Size of List of Label Images 64
# global step 17 learning rate 0.0010 step-time 4.49 loss 0.74
# Batch Size of List of Filenames 64
# Batch Size of List of Label Images 64
# global step 18 learning rate 0.0010 step-time 4.45 loss 0.67
# Batch Size of List of Filenames 64
# Batch Size of List of Label Images 64
# global step 19 learning rate 0.0010 step-time 5.20 loss 0.70
# Batch Size of List of Filenames 64
# Batch Size of List of Label Images 64
# global step 20 learning rate 0.0010 step-time 4.29 loss 0.70
# Batch Size of List of Filenames 64
# Batch Size of List of Label Images 64
# global step 21 learning rate 0.0010 step-time 3.86 loss 0.69
# Batch Size of List of Filenames 64
# Batch Size of List of Label Images 64
# global step 22 learning rate 0.0010 step-time 3.69 loss 0.69
# Batch Size of List of Filenames 64
# Batch Size of List of Label Images 64
# global step 23 learning rate 0.0010 step-time 4.13 loss 0.67
# Batch Size of List of Filenames 64
# Batch Size of List of Label Images 64
# global step 24 learning rate 0.0010 step-time 5.24 loss 0.70
# Batch Size of List of Filenames 64
# Batch Size of List of Label Images 64
# global step 25 learning rate 0.0010 step-time 3.95 loss 0.69
# Batch Size of List of Filenames 64
# Batch Size of List of Label Images 64
# global step 26 learning rate 0.0010 step-time 4.03 loss 0.67
# Batch Size of List of Filenames 64
# Batch Size of List of Label Images 64
# global step 27 learning rate 0.0010 step-time 4.72 loss 0.68
# Batch Size of List of Filenames 64
# Batch Size of List of Label Images 64
# global step 28 learning rate 0.0010 step-time 4.00 loss 0.67
# Batch Size of List of Filenames 64
# Batch Size of List of Label Images 64
# global step 29 learning rate 0.0010 step-time 4.92 loss 0.68
# Batch Size of List of Filenames 64
# Batch Size of List of Label Images 64
# global step 30 learning rate 0.0010 step-time 4.84 loss 0.68
# Batch Size of List of Filenames 64
# Batch Size of List of Label Images 64
# global step 31 learning rate 0.0010 step-time 3.76 loss 0.66
# Batch Size of List of Filenames 64
# Batch Size of List of Label Images 64
# global step 32 learning rate 0.0010 step-time 3.64 loss 0.69
# Batch Size of List of Filenames 64
# Batch Size of List of Label Images 64
# global step 33 learning rate 0.0010 step-time 3.70 loss 0.66
# Batch Size of List of Filenames 64
# Batch Size of List of Label Images 64
# global step 34 learning rate 0.0010 step-time 3.73 loss 0.67
# Batch Size of List of Filenames 64
# Batch Size of List of Label Images 64
# global step 35 learning rate 0.0010 step-time 4.04 loss 0.67
# Batch Size of List of Filenames 64
# Batch Size of List of Label Images 64
# global step 36 learning rate 0.0010 step-time 3.64 loss 0.67
# Batch Size of List of Filenames 64
# Batch Size of List of Label Images 64
# global step 37 learning rate 0.0010 step-time 4.74 loss 0.69
# Batch Size of List of Filenames 64
# Batch Size of List of Label Images 64
# global step 38 learning rate 0.0009 step-time 4.33 loss 0.66
# Batch Size of List of Filenames 64
# Batch Size of List of Label Images 64
# global step 39 learning rate 0.0009 step-time 4.16 loss 0.69
# Batch Size of List of Filenames 64
# Batch Size of List of Label Images 64
# global step 40 learning rate 0.0009 step-time 4.92 loss 0.66
# Batch Size of List of Filenames 64
# Batch Size of List of Label Images 64
# global step 41 learning rate 0.0009 step-time 4.04 loss 0.68
# Batch Size of List of Filenames 64
# Batch Size of List of Label Images 64
# global step 42 learning rate 0.0009 step-time 4.63 loss 0.65
# Batch Size of List of Filenames 64
# Batch Size of List of Label Images 64
# global step 43 learning rate 0.0009 step-time 4.31 loss 0.69
# Batch Size of List of Filenames 64
# Batch Size of List of Label Images 64
# global step 44 learning rate 0.0009 step-time 4.86 loss 0.63
# Batch Size of List of Filenames 64
# Batch Size of List of Label Images 64
# global step 45 learning rate 0.0009 step-time 4.49 loss 0.67
# Batch Size of List of Filenames 64
# Batch Size of List of Label Images 64
# global step 46 learning rate 0.0009 step-time 4.08 loss 0.67
# Batch Size of List of Filenames 64
# Batch Size of List of Label Images 64
# global step 47 learning rate 0.0009 step-time 4.72 loss 0.66
# Batch Size of List of Filenames 64
# Batch Size of List of Label Images 64
# global step 48 learning rate 0.0009 step-time 4.56 loss 0.65
# Batch Size of List of Filenames 64
# Batch Size of List of Label Images 64
# global step 49 learning rate 0.0009 step-time 4.66 loss 0.68
# Batch Size of List of Filenames 64
# Batch Size of List of Label Images 64
# global step 50 learning rate 0.0009 step-time 4.47 loss 0.66
# Batch Size of List of Filenames 64
# Batch Size of List of Label Images 64
# global step 51 learning rate 0.0009 step-time 4.35 loss 0.65
# Batch Size of List of Filenames 64
# Batch Size of List of Label Images 64
# global step 52 learning rate 0.0009 step-time 4.51 loss 0.69
# Batch Size of List of Filenames 64
# Batch Size of List of Label Images 64
# global step 53 learning rate 0.0009 step-time 4.45 loss 0.66
# Batch Size of List of Filenames 64
# Batch Size of List of Label Images 64
# global step
loss 0.53
# Batch Size of List of Filenames 64
# Batch Size of List of Label Images 64
# global step 207 learning rate 0.0006 step-time 3.72 loss 0.56
# Batch Size of List of Filenames 64
# Batch Size of List of Label Images 64
# global step 208 learning rate 0.0006 step-time 3.89 loss 0.54
# Batch Size of List of Filenames 64
# Batch Size of List of Label Images 64
# global step 209 learning rate 0.0006 step-time 3.59 loss 0.56
# Batch Size of List of Filenames 64
# Batch Size of List of Label Images 64
# global step 210 learning rate 0.0006 step-time 3.76 loss 0.49
# Batch Size of List of Filenames 64
# Batch Size of List of Label Images 64
# global step 211 learning rate 0.0006 step-time 3.93 loss 0.54
# Batch Size of List of Filenames 64
# Batch Size of List of Label Images 64
# global step 212 learning rate 0.0006 step-time 4.02 loss 0.56
# Batch Size of List of Filenames 64
# Batch Size of List of Label Images 64
# global step 213 learning rate 0.0006 step-time 4.31 loss 0.57
# Batch Size of List of Filenames 64
# Batch Size of List of Label Images 64
# global step 214 learning rate 0.0006 step-time 4.87 loss 0.53
# Batch Size of List of Filenames 64
# Batch Size of List of Label Images 64
# global step 215 learning rate 0.0006 step-time 4.72 loss 0.59
# Batch Size of List of Filenames 64
# Batch Size of List of Label Images 64
# global step 216 learning rate 0.0006 step-time 4.44 loss 0.57
# Batch Size of List of Filenames 64
# Batch Size of List of Label Images 64
# global step 217 learning rate 0.0006 step-time 5.25 loss 0.52
# Batch Size of List of Filenames 64
# Batch Size of List of Label Images 64
# global step 218 learning rate 0.0006 step-time 4.96 loss 0.52
# Batch Size of List of Filenames 64
# Batch Size of List of Label Images 64
# global step 219 learning rate 0.0006 step-time 3.77 loss 0.58
# Batch Size of List of Filenames 64
# Batch Size of List of Label Images 64
# global step 220 learning rate 0.0006 step-time 4.37 loss 0.54
# Batch Size of List of Filenames 64
# Batch Size of List of Label Images 64
# global step 221 learning rate 0.0006 step-time 4.11 loss 0.59
# Batch Size of List of Filenames 64
# Batch Size of List of Label Images 64
# global step 222 learning rate 0.0006 step-time 3.90 loss 0.53
# Batch Size of List of Filenames 64
# Batch Size of List of Label Images 64
# global step 223 learning rate 0.0006 step-time 4.28 loss 0.51
# Batch Size of List of Filenames 64
# Batch Size of List of Label Images 64
# global step 224 learning rate 0.0006 step-time 3.73 loss 0.57
# Batch Size of List of Filenames 64
# Batch Size of List of Label Images 64
# global step 225 learning rate 0.0006 step-time 3.66 loss 0.56
# Batch Size of List of Filenames 64
# Batch Size of List of Label Images 64
# global step 226 learning rate 0.0006 step-time 4.30 loss 0.59
# Batch Size of List of LAST Filenames 64
# Batch Size of List of LAST Label Images 64
# global step 227 learning rate 0.0006 step-time 4.53 loss 0.53

# %%
def initialize_params_for_resuming_training_from_checkpoint():
    params_initialization_for_resume_training = {}
    params_initialization_for_resume_training['resume_training'] = True
    params_initialization_for_resume_training['training_path_zero_labeled'] = "data/0/training_filenames_02.txt"
    params_initialization_for_resume_training['training_path_one_labeled'] = "data/1/training_filenames_02.txt"
    params_initialization_for_resume_training['data_dir'] = 'data'
    params_initialization_for_resume_training['logs_dir'] = 'logs'
    params_initialization_for_resume_training['max_steps'] = 4
    params_initialization_for_resume_training['num_epochs'] = 1
    params_initialization_for_resume_training['batch_size'] = 32
    params_initialization_for_resume_training['use_preprocessing'] = False
    return pac.initialize_params(experiment_directory_name,
           experiment_directory_suffix,
           "resume_training",
           params_initialization_for_resume_training=params_initialization_for_resume_training)

# %%
params, filenames_of_resume_training_images, labels_of_resume_training_images = initialize_params_for_resuming_training_from_checkpoint()
if params != None and filenames_of_resume_training_images != None and labels_of_resume_training_images != None:
    pac.run_training_with_feed_dictionary(params, "/gpu:0", filenames_of_resume_training_images, labels_of_resume_training_images)

# %%
def initialize_params_for_evaluation_from_checkpoint():
    params_initialization_for_evaluation = {}
    params_initialization_for_evaluation['evaluate_model'] = True
    params_initialization_for_evaluation['resume_training'] = False
    params_initialization_for_evaluation['stage_of_development'] = "evaluation"
    params_initialization_for_evaluation['dev_path_zero_labeled'] = "data/0/dev_filenames_02.txt"
    params_initialization_for_evaluation['dev_path_one_labeled'] = "data/1/dev_filenames_02.txt"
    params_initialization_for_evaluation['data_dir'] = 'data'
    params_initialization_for_evaluation['logs_dir'] = 'logs'
    params_initialization_for_evaluation['max_steps'] = None
    params_initialization_for_evaluation['num_epochs'] = 1
    params_initialization_for_evaluation['batch_size'] = 32
    params_initialization_for_evaluation['use_preprocessing'] = False
    return pac.initialize_params(experiment_directory_name,
                                    experiment_directory_suffix,
                                    "evaluation",
                                    params_initialization_for_evaluation=params_initialization_for_evaluation)

# %%
params, filenames_of_evaluation_images, labels_of_evaluation_images = initialize_params_for_evaluation_from_checkpoint()
if params != None and filenames_of_evaluation_images != None and labels_of_evaluation_images != None:
    pac.evaluate_model_with_feed_dictionary(params, "/gpu:0", filenames_of_evaluation_images, labels_of_evaluation_images)
# Out:
# Reading model parameters from logs/0000000018_experiment_2018-01-17_10:08:53_hygiene_detector_for_sensor_02_without_preprocessing/translate.ckpt-227
# Done creating the model.
# False
# Length of Time (in seconds) for preprocessing 13.112987041473389
# Accuracy For Current Batch: 0.875
# Accuracy For Current Batch: 0.84375
# Accuracy For Current Batch: 0.9375
# Accuracy For Current Batch: 0.9375
# Accuracy For Current Batch: 0.9375
# Accuracy For Current Batch: 0.875
# Accuracy For Current Batch: 0.84375
# Accuracy For Current Batch: 0.90625
# Accuracy For Current Batch: 0.90625
# Accuracy For Current Batch: 0.9375
# Accuracy For Current Batch: 0.84375
# Accuracy For Current Batch: 0.78125
# Accuracy For Current Batch: 0.875
# Accuracy For Current Batch: 0.78125
# Accuracy For Current Batch: 0.96875
# Accuracy For Current Batch: 0.90625
# Accuracy For Current Batch: 0.9375
# Accuracy For Current Batch: 0.8125
# Accuracy For Current Batch: 0.90625
# Accuracy For Current Batch: 0.90625
# Accuracy For Current Batch: 0.96875
# Accuracy For Current Batch: 0.90625
# Accuracy For Current Batch: 1.0
# Accuracy For Current Batch: 0.78125
# Accuracy For Current Batch: 0.875
# Accuracy For Current Batch: 0.90625
# Accuracy For Current Batch: 0.84375
# Accuracy For Current Batch: 0.84375
# Accuracy For Current Batch: 0.84375
# Accuracy For Current Batch: 0.9375
# Accuracy For Current Batch: 0.84375
# Accuracy For Current Batch: 0.875
# Accuracy For Current Batch: 0.9375
# Accuracy For Current Batch: 0.9375
# Accuracy For Current Batch: 0.90625
# Accuracy For Current Batch: 0.8125
# Accuracy For Current Batch: 0.75
# Accuracy For Current Batch: 0.875
# Accuracy For Current Batch: 0.75
# Accuracy For Current Batch: 0.9375
# Accuracy For Current Batch: 0.90625
# Accuracy For Current Batch: 0.96875
# Accuracy For Current Batch: 0.78125
# Accuracy For Current Batch: 0.90625
# Accuracy For Current Batch: 0.84375
# Accuracy For Current Batch: 0.9375
# Accuracy For Current Batch: 0.90625
# Accuracy For Current Batch: 0.90625
# Accuracy For Current Batch: 0.8125
# Accuracy For Current Batch: 0.875
# Accuracy For Current Batch: 0.875
# Accuracy For Current Batch: 0.875
# Accuracy For Current Batch: 0.90625
# Accuracy For Current Batch: 0.9375
# Accuracy For Current Batch: 0.875
# Accuracy For Current Batch: 0.84375
# Accuracy For Current Batch: 0.84375
# Accuracy For Current Batch: 0.96875
# Accuracy For Current Batch: 0.9375
# Accuracy For Current Batch: 0.90625
# Accuracy For Current Batch: 0.6875
# Accuracy For Current Batch: 0.875
# Accuracy For Current Batch: 0.90625
# Accuracy For Current Batch: 0.875
# Accuracy For Current Batch: 0.9375
# Accuracy For Current Batch: 0.875
# Accuracy For Current Batch: 0.96875
# Accuracy For Current Batch: 0.75
# Accuracy For Current Batch: 0.84375
# Accuracy For Current Batch: 0.875
# Accuracy For Current Batch: 0.96875
# Accuracy For Current Batch: 0.9375
# Accuracy For Current Batch: 0.90625
# Accuracy For Current Batch: 0.8125
# Accuracy For Current Batch: 0.9375
# Accuracy For Current Batch: 0.84375
# Accuracy For Current Batch: 0.9375
# Accuracy For Current Batch: 0.875
# Accuracy For Current Batch: 0.96875
# Accuracy For Current Batch: 0.875
# Accuracy For Current Batch: 0.8125
# Accuracy For Current Batch: 0.84375
# Accuracy For Current Batch: 0.96875
# Accuracy For Current Batch: 0.90625
# Accuracy For Current Batch: 1.0
# Accuracy For Current Batch: 0.78125
# Accuracy For Current Batch: 0.84375
# Accuracy For Current Batch: 0.875
# Accuracy For Current Batch: 0.875
# Accuracy For Current Batch: 0.9375
# Accuracy For Current Batch: 0.9375
# Accuracy For Current Batch: 0.875
# Accuracy For Current Batch: 0.84375
# Accuracy For Current Batch: 0.90625
# Accuracy For Current Batch: 0.9375
# Accuracy For Current Batch: 0.90625
# Accuracy For Current Batch: 0.9375
# Accuracy For Current Batch: 0.84375
# Accuracy For Current Batch: 0.78125
# Accuracy For Current Batch: 0.8125
# Accuracy For Current Batch: 0.84375
# Accuracy For Current Batch: 0.9375
# Accuracy For Current Batch: 0.9375
# Accuracy For Current Batch: 0.96875
# Accuracy For Current Batch: 0.84375
# Accuracy For Current Batch: 0.875
# Accuracy For Current Batch: 0.9375
# Accuracy For Current Batch: 0.90625
# Accuracy For Current Batch: 0.90625
# Accuracy For Current Batch: 0.875
# Accuracy For Current Batch: 0.84375
# Accuracy For Current Batch: 0.8125
# Accuracy For Current Batch: 0.84375
# Accuracy For Current Batch: 0.9375
# Accuracy For Current Batch: 0.90625
# Accuracy For Current Batch: 0.90625
# Accuracy For Current Batch: 0.90625
# Accuracy For Current Batch: 0.90625
# Accuracy For Current Batch: 0.90625
# Accuracy For Current Batch: 0.9375
# Accuracy For Current Batch: 0.90625
# Accuracy For Current Batch: 1.0
# Accuracy For Current Batch: 0.78125
# Accuracy For Current Batch: 0.8125
# Accuracy For Current Batch: 0.90625
# Accuracy For Current Batch: 0.90625
# Accuracy For Current Batch: 0.875
# Accuracy For Current Batch: 0.875
# Accuracy For Current Batch: 0.90625
# Accuracy For Current Batch: 0.90625
# Average Accuracy Across Batches: 0.8858173076923077
